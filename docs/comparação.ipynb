# %% [markdown]
# # Comparação dos resultados

# %% [markdown]
# Os testes envolvendo 2,3 e 4 objetivos de todos os benchmarks mostraram resultados satisfatórios para todos os 3 algoritmos testados, nesse contexto a análise seguinte foca no resultado para 5 objetivos, em que os algoritmos clássicos mostraram vantagem clara.

# %% [markdown]
# Para os benchmarks realizados o MEAMT mostrou baixa diversidade em comparação com o do MOEA/D e NSGA3, isso é evidenciado tanto pelo menor valor de hypervolume no fim da evolução quando pela análise dos indivíduos da população final, além disso, o algoritmo em si foi mais ineficiente, levando mais tempo para execução.

# %% [markdown]
# Em especial, para o DTLZ3, o MEAMT mostrou incapacidade escapar de mínimos locais gerados pela função Rastringin subjacente.Uma análise das variáveis de decisão das soluções não dominadas finais revela um forte enviesamento nas variáveis de posição (tendendo aos extremos 0 ou 1). O algoritmo sucumbe à armadilha clássica do DTLZ3: a incapacidade de explorar o espaço das variáveis de posição enquanto tenta simultaneamente convergir as variáveis de distância (que deveriam se estabilizar em 0.5) para minimizar a função de penalidade.

# %% [markdown]
# O gráficos abaixo demonstram essa vulnerabilidade:

# %%
from IPython.display import Image, display

display(Image(filename='../Conjunto de Resultados/Var-dtlz1-5obj.png'))

display(Image(filename='../Conjunto de Resultados/Var2-dtlz1-5obj.png'))

display(Image(filename='../Conjunto de Resultados/Var-dtlz2-5obj.png'))

display(Image(filename='../Conjunto de Resultados/Var2-dtlz2-5obj.png'))

display(Image(filename='../Conjunto de Resultados/Var-dtlz3-5obj.png'))

display(Image(filename='../Conjunto de Resultados/Var2-dtlz3-5obj.png'))

display(Image(filename='../Conjunto de Resultados/Var-dtlz4-5obj.png'))

display(Image(filename='../Conjunto de Resultados/Var2-dtlz4-5obj.png'))

# %% [markdown]
# Para efeito de comparação, os resultados do NSGA3 foram incluídos abaixo:

# %%
from IPython.display import Image, display

display(Image(filename='../Conjunto de Resultados/Var-dtlz1-5obj_b.png'))

display(Image(filename='../Conjunto de Resultados/Var2-dtlz1-5obj_b.png'))

display(Image(filename='../Conjunto de Resultados/Var-dtlz2-5obj_b.png'))

display(Image(filename='../Conjunto de Resultados/Var2-dtlz2-5obj_b.png'))

display(Image(filename='../Conjunto de Resultados/Var-dtlz3-5obj_b.png'))

display(Image(filename='../Conjunto de Resultados/Var2-dtlz3-5obj_b.png'))

display(Image(filename='../Conjunto de Resultados/Var-dtlz4-5obj_b.png'))

display(Image(filename='../Conjunto de Resultados/Var2-dtlz4-5obj_b.png'))

# %% [markdown]
# Por fim, elaborou-se uma tabela com os hypervolumes obtidos e os valores finais de IGD+, nesse caso, há empate técnico entre o NSGA3 e o MOEA/D pois os dois se aproximam da fronteira real pareto, enquanto o MEAMT tem um resultado aquém do esperado.

# %% [markdown]
# | Algoritmo | Benchmark | Hypervolume (HV) | IGD+ | Tempo (s) |
# | :--- | :---: | :---: | :---: | :---: |
# | **NSGA-III** | DTLZ1 | 1.610 | 0.04 | 20 |
# | **MOEA/D** | DTLZ1 | 1.610 | 0.04 | 1038
# | **MEAMT** | DTLZ1 | 1.601 | 0.112 | 765
# | **NSGA-III** | DTLZ2 | 1.306 | 0.081 | 21 |
# | **MOEA/D** | DTLZ2 | 1.308 | 0.080 | 685
# | **MEAMT** | DTLZ2 | 0.994 | 0.172 | 400
# | **NSGA-III** | DTLZ3 | 1.250 | 0.097 | 20 |
# | **MOEA/D** | DTLZ3 | 1.297 | 0.085 | 765
# | **MEAMT** | DTLZ3 | 0.5 | 0.478 | 774
# | **NSGA-III** | DTLZ4 |1.308 | 0.076 | 22 |
# | **MOEA/D** | DTLZ4 | 1.150 | 0.140 | 177
# | **MEAMT** | DTLZ4 | 0.781 | 0.207 | 402
